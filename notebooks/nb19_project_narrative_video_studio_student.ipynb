# %% [markdown]
# # Executive Narrative - Slide-Style Story + Conference Video Plan
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/main/notebooks/figures/mgmt_474_ai_logo_02-modified.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>MGMT47400 Predictive Analytics</center>
# # <center>Professor: Davi Moreira </center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/nb19_project_narrative_video_studio.ipynb)
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Convert technical work into an executive-ready slide narrative
# 2. Build a clear "problem → approach → results → recommendation → risks" flow
# 3. Create credible visuals (comparison table, key plots, decision policy)
# 4. Script a short conference video (tight, evidence-based, non-technical)
# 5. Finalize the project deliverable package
#
# ---

# %% [markdown]
# ## 1. Setup: Imports and Display Settings
#
# This notebook focuses on communication rather than modelling, but it still needs a clean technical foundation. The imports below load pandas (for storyboard and checklist DataFrames), matplotlib/seaborn (for example comparison tables), and json (for saving script templates and Gemini prompts). We lock `RANDOM_SEED = 474` for consistency with all prior notebooks and print the date so narrative materials are timestamped.

# %% [markdown]
# > **📋 Participation Reminder:** This notebook contains **2 PAUSE-AND-DO exercises**. You are expected to complete all exercises before submitting your notebook.
#
# ---

# %% [markdown]
# ## 💼 Why This Matters: Telling the Story Behind the Numbers
#
# The hospital board meeting is next week. You've spent weeks building, tuning, and validating the **State Health Department** screening model. Now comes the hardest part: explaining it to non-technical decision-makers who will approve (or reject) the deployment.
#
# The CEO doesn't want to see a confusion matrix — she wants to know: *"Will this save lives? How much will it cost? What are the risks?"* Translating technical results into a compelling business narrative is a skill that separates good analysts from great ones. Your ability to communicate determines whether your model ever gets used.
#
# > **Today's focus:** Structuring a project narrative that translates technical results into stakeholder-ready communication, with clear slides, scripts, and a compelling story arc.
#
# > **A question that often comes up here:** *"If the model speaks for itself through CV scores and plots, why do I need a separate narrative at all?"* Because stakeholders do not make decisions from CV scores — they make decisions from *stories*. An executive cannot act on "ROC-AUC 0.92" without the five-sentence story that gives it meaning: what problem are we solving, what did we try, what worked, what to do next, what are the risks. The narrative is what translates technical work into a business decision; without it, the technical work is a pile of numbers no one signs off on.
#
# ---

# %%
# Install required packages (uncomment if needed)
# !pip install pandas numpy matplotlib seaborn --quiet

# Core imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import json
import warnings

# Display settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 3)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

print("✓ Setup complete!")
print(f"Date: {datetime.now().strftime('%Y-%m-%d')}")

# %% [markdown]
# **Reading the output:**
#
# The `Setup complete!` line confirms that pandas, numpy, matplotlib, seaborn,
# and the `json` module are all available. The printed date stamps when the
# notebook was last executed, which is helpful for version-tracking your
# narrative materials.
#
# **Why this matters:** Even in a narrative-focused notebook, a clean setup
# cell ensures that all helper code (DataFrames for checklists, CSV exports)
# will run without errors.
#
# ---

# %% [markdown]
# ## 2. Executive Narrative Structure: The Five-Act Framework
#
# ### Why Structure Matters
#
# > **"If your audience has to work to understand you, they won't."**
# > The hospital board meeting is next week. HomeValue's CEO has 15 minutes between calls. Neither audience will read a 40-cell notebook — they need a clear, structured story that answers three questions: What's the problem? What did you find? What should we do?
#
# ### 2.1 The Five-Act Framework
#
# **Act 1: The Problem (1-2 slides)**
# - What business problem are you solving? (HomeValue: inaccurate property pricing. Health Dept: missed cancers in screening.)
# - Why does it matter? (Quantify: "$X in lost revenue" or "Y missed diagnoses per year")
# - What's the current baseline/status quo?
#
# **Act 2: The Approach (2-3 slides)**
# - What data did you use? (California Housing, Breast Cancer Wisconsin, or your project dataset)
# - What methods did you try? (Describe in non-technical terms: "We tested several prediction approaches")
# - How did you evaluate success? (Validation strategy, cost-based thresholds)
#
# **Act 3: The Results (2-3 slides)**
# - What did you find? (Key metrics translated to business impact)
# - How does it compare to baseline? (This is the "so what?" slide)
# - What are the key performance metrics? (Lead with the metric stakeholders care about)
#
# **Act 4: The Recommendation (1-2 slides)**
# - What action should we take? (Deploy, pilot, invest in more data, etc.)
# - What's the expected business impact? ("Reduces pricing error by $20k" or "Catches 35% more cancers")
# - What's the implementation plan? (Timeline, resources, milestones)
#
# **Act 5: The Risks (1-2 slides)**
# - What could go wrong? (Model degrades, costs change, new populations)
# - What are the limitations? (Segment-specific errors, data gaps, calibration drift)
# - What monitoring is needed? (Reference the monitoring plan from the deployment notebook)
#
# ### 2.2 The One-Idea-Per-Slide Rule
#
# **Each slide should have:**
# - One clear headline (full sentence, not a topic)
# - One key visual or table
# - 2-3 supporting bullets (optional)
#
# **Avoid:**
# - Walls of text
# - Multiple competing messages
# - Technical jargon without explanation
# - Overcrowded visualizations

# %% [markdown]
# ## 3. Slide Storyboard Builder
#
# ### 3.1 Storyboard Template
#
# A storyboard maps your entire presentation before you open PowerPoint. Each row represents one slide and captures four elements: the section it belongs to, a full-sentence headline, the key visual, and speaker-note guidance. Whether you are presenting HomeValue's pricing tool to the CEO or the screening model to the Health Department's board, the storyboard ensures your narrative flows logically from problem through evidence to action.
#
# Planning all slides in a table first prevents the most common mistake: building slides one at a time and ending up with a technically impressive deck that tells no coherent story.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create storyboard DataFrame with 11 slides: title, problem, opportunity, data, methodology, finding, comparison, importance, recommendation, limitations, next steps. Columns: Slide, Section, Headline, Visual, Bullets, Speaker Notes. Save to CSV."
# >
# > **After running, verify:**
# > - 11 rows covering all presentation sections
# > - Headlines as full sentences
# > - Speaker Notes provide guidance
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Slide storyboard template
storyboard = pd.DataFrame([
    {
        'Slide': 1,
        'Section': 'Title',
        'Headline': 'Project Title: [Your Compelling Title]',
        'Visual': 'Project logo or key visual',
        'Bullets': 'Your Name | Date | Context',
        'Speaker Notes': 'Welcome and preview the key finding in 1 sentence'
    },
    {
        'Slide': 2,
        'Section': 'Problem',
        'Headline': '[Problem statement as full sentence]',
        'Visual': 'Current state visual (cost, error rate, etc.)',
        'Bullets': '• Quantify the problem\n• Current baseline\n• Why it matters',
        'Speaker Notes': 'Establish urgency and business context'
    },
    {
        'Slide': 3,
        'Section': 'Problem',
        'Headline': 'Opportunity: What success would look like',
        'Visual': 'Target state or goal visualization',
        'Bullets': '• Success metric\n• Expected impact\n• Stakeholder benefit',
        'Speaker Notes': 'Paint the picture of success'
    },
    {
        'Slide': 4,
        'Section': 'Approach',
        'Headline': 'Data: What we analyzed',
        'Visual': 'Data summary table or sample visualization',
        'Bullets': '• Data sources\n• Time period\n• Key features',
        'Speaker Notes': 'Establish data credibility and scope'
    },
    {
        'Slide': 5,
        'Section': 'Approach',
        'Headline': 'Method: [Non-technical description of approach]',
        'Visual': 'Simple workflow diagram',
        'Bullets': '• Analysis approach\n• Validation strategy\n• Success criteria',
        'Speaker Notes': 'Explain methodology without jargon'
    },
    {
        'Slide': 6,
        'Section': 'Results',
        'Headline': '[Key finding #1 as full sentence]',
        'Visual': 'Primary result visualization',
        'Bullets': '• Specific result\n• Comparison to baseline\n• Statistical confidence',
        'Speaker Notes': 'Lead with the most important finding'
    },
    {
        'Slide': 7,
        'Section': 'Results',
        'Headline': 'Performance: [Model name] outperforms baseline by X%',
        'Visual': 'Model comparison table or chart',
        'Bullets': '• Key metrics\n• Improvement vs baseline\n• Validation results',
        'Speaker Notes': 'Quantify improvement with confidence'
    },
    {
        'Slide': 8,
        'Section': 'Results',
        'Headline': 'Key drivers: [Top 3 factors that matter most]',
        'Visual': 'Feature importance chart',
        'Bullets': '• Factor #1\n• Factor #2\n• Factor #3',
        'Speaker Notes': 'Explain what drives predictions'
    },
    {
        'Slide': 9,
        'Section': 'Recommendation',
        'Headline': 'Recommendation: [Specific action to take]',
        'Visual': 'Decision policy or implementation plan',
        'Bullets': '• Specific action\n• Expected business impact\n• Timeline',
        'Speaker Notes': 'Clear call to action with expected ROI'
    },
    {
        'Slide': 10,
        'Section': 'Risks',
        'Headline': 'Limitations and risks we are monitoring',
        'Visual': 'Risk matrix or monitoring dashboard',
        'Bullets': '• Key limitations\n• Mitigation strategies\n• Monitoring plan',
        'Speaker Notes': 'Demonstrate awareness and responsibility'
    },
    {
        'Slide': 11,
        'Section': 'Conclusion',
        'Headline': 'Next steps and Q&A',
        'Visual': 'Timeline or roadmap',
        'Bullets': '• Immediate next steps\n• Success metrics\n• Contact info',
        'Speaker Notes': 'Summarize and invite questions'
    }
])

print("=== SLIDE STORYBOARD TEMPLATE ===")
print(storyboard.to_string(index=False))

# Save storyboard
storyboard.to_csv('slide_storyboard.csv', index=False)
print("\n✓ Storyboard template saved to slide_storyboard.csv")

# %% [markdown]
# **Reading the output:**
#
# The printed storyboard has **11 rows** -- one per slide -- each showing the
# slide number, section label (Title, Problem, Approach, Results,
# Recommendation, Risks, Conclusion), a placeholder headline, visual
# description, bullet points, and speaker notes. Reading it top to bottom
# should feel like a coherent story: problem setup, evidence gathering,
# findings, action, and caveats. The CSV export lets you open the storyboard
# in a spreadsheet for collaborative editing.
#
# **Key takeaway:** A good storyboard reads like an executive summary even
# without the visuals. If the headline column alone does not tell a clear
# story, the presentation needs restructuring.
#
# ---

# %% [markdown]
# **Reading the output:**
#
# The `Setup complete!` line with today's date confirms that pandas, numpy, matplotlib, seaborn, and the `json` module are all available. No modelling libraries are needed because this notebook is about translating your existing technical results — whether from HomeValue's pricing tool or the Health Department's screening model — into stakeholder-ready communication.
#
# **Why this matters:** Even a narrative-focused notebook should run cleanly from top to bottom. If you cannot set up your environment reproducibly, stakeholders will question whether your analysis is reproducible either.
#
# ---

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 1 (5 minutes)
#
# **Task:** Create a 10-slide outline (titles + 2 bullets each).
#
# **Instructions:**
# 1. Use the storyboard template above as a starting point
# 2. Customize each slide for YOUR project:
#    - Replace placeholders with your specific content
#    - Write headlines as complete sentences
#    - Add 2-3 specific bullets per slide
# 3. Focus on the story arc: problem → approach → results → action → risks
#
# **What to include:**
# - Slide number and section
# - Complete sentence headline
# - 2-3 supporting bullets
# - Visual description
#
# ---

# %% [markdown]
# ### YOUR SLIDE OUTLINE HERE:
#
# **Slide 1: [Title]**
# - [Headline]
# - Bullets:
#   - [Bullet 1]
#   - [Bullet 2]
# - Visual: [Description]
#
# **Slide 2: [Section]**
# - [Headline]
# - Bullets:
#   - [Bullet 1]
#   - [Bullet 2]
# - Visual: [Description]
#
# [Continue for all 10 slides...]
#
# ---

# %% [markdown]
# ## 4. Required Visuals Checklist
#
# ### 4.1 Essential Visuals for Model Communication
#
# Every stakeholder presentation — whether to HomeValue's pricing team or the Health Department's board — needs a core set of visuals. Missing a key chart (e.g., no baseline comparison) is one of the most common presentation shortcomings. The checklist below ensures you cover all the bases.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create visuals_checklist DataFrame listing required visualizations: Model Comparison, Metrics Chart, Feature Importance, Confusion Matrix, ROC Curve, Data Overview, Monitoring Dashboard. Include Purpose, Must Include, Design Tips. Save to CSV."
# >
# > **After running, verify:**
# > - At least 7 visual types
# > - Design Tips are actionable
# > - Completed column for tracking
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Required visuals checklist
visuals_checklist = pd.DataFrame([
    {
        'Visual Type': 'Model Comparison Table',
        'Purpose': 'Show model performance vs baseline',
        'Must Include': 'Model name, accuracy, precision, recall, F1',
        'Design Tips': 'Highlight best performer, use color sparingly',
        'Completed': '□'
    },
    {
        'Visual Type': 'Performance Metrics Chart',
        'Purpose': 'Visualize key metrics',
        'Must Include': 'Clear axis labels, baseline reference line',
        'Design Tips': 'Use bar chart for comparison, include error bars if available',
        'Completed': '□'
    },
    {
        'Visual Type': 'Feature Importance',
        'Purpose': 'Show what drives predictions',
        'Must Include': 'Top 5-10 features, importance scores',
        'Design Tips': 'Horizontal bar chart, descriptive feature names',
        'Completed': '□'
    },
    {
        'Visual Type': 'Confusion Matrix',
        'Purpose': 'Show prediction accuracy by class',
        'Must Include': 'True/predicted labels, counts and percentages',
        'Design Tips': 'Use heatmap with annotations, explain TP/FP/TN/FN',
        'Completed': '□'
    },
    {
        'Visual Type': 'ROC Curve or PR Curve',
        'Purpose': 'Show trade-offs at different thresholds',
        'Must Include': 'AUC score, baseline diagonal, operating point',
        'Design Tips': 'Include explanation for non-technical audience',
        'Completed': '□'
    },
    {
        'Visual Type': 'Business Impact Chart',
        'Purpose': 'Translate metrics to business outcomes',
        'Must Include': 'Cost/benefit analysis, ROI projection',
        'Design Tips': 'Use currency units, show before/after comparison',
        'Completed': '□'
    },
    {
        'Visual Type': 'Decision Policy',
        'Purpose': 'Show how model will be used',
        'Must Include': 'Threshold, action rules, edge case handling',
        'Design Tips': 'Use flowchart or decision tree format',
        'Completed': '□'
    },
    {
        'Visual Type': 'Monitoring Dashboard',
        'Purpose': 'Show what will be tracked',
        'Must Include': 'Key metrics, thresholds, update frequency',
        'Design Tips': 'Simple mockup, focus on actionable signals',
        'Completed': '□'
    }
])

print("=== REQUIRED VISUALS CHECKLIST ===")
print(visuals_checklist.to_string(index=False))

# Save checklist
visuals_checklist.to_csv('visuals_checklist.csv', index=False)
print("\n✓ Visuals checklist saved to visuals_checklist.csv")

# %% [markdown]
# **Reading the output:**
#
# The visuals checklist lists **eight required visual types**: Model
# Comparison Table, Performance Metrics Chart, Feature Importance, Confusion
# Matrix, ROC/PR Curve, Business Impact Chart, Decision Policy, and
# Monitoring Dashboard. Each row explains the visual's purpose, what it must
# include, and design tips. The `Completed` column starts with empty
# checkboxes for you to tick off as you create each visual.
#
# **Why this matters:** Missing a key visual (e.g., no baseline comparison)
# is one of the most common presentation shortcomings. This checklist
# prevents that.
#
# > **A question that often comes up here:** *"Should every results slide have a plot, or can some be text?"* Results slides should have exactly one clear visual each — a plot, a table, or a callout number. Pure-text results slides are where audience attention dies. The rule: if a slide would work as an audio-only podcast, it should not be a slide. Conversely, a heavy table that the audience cannot read from the back row is also a failure — strip it down to 3–5 rows or replace with a summary bar chart.
#
# ---

# %% [markdown]
# **Reading the output:**
#
# The storyboard has **11 rows** — one per slide — each showing slide number, section (Title, Problem, Approach, Results, Recommendation, Risks, Conclusion), a placeholder headline, visual description, bullet points, and speaker notes. Reading the headline column top to bottom should tell a coherent story even without the visuals: problem setup, evidence gathering, findings, action, and caveats.
#
# The CSV export lets you open the storyboard in a spreadsheet for collaborative editing — useful when HomeValue's marketing team or the Health Department's communications staff want input on the narrative.
#
# **Key takeaway:** A good storyboard reads like an executive summary. If the headline column alone does not tell a clear, compelling story, the presentation needs restructuring before you create a single slide.
#
# ---

# %% [markdown]
# ### 4.3 Example: Model Comparison Table
#
# A side-by-side model comparison table is often the single most persuasive visual in a data-science presentation. For HomeValue, it shows the pricing team how the champion model stacks up against the baseline and alternatives in terms of MAE, R², and business impact. For the Health Department, it shows the board how different models trade off recall (catching cancers) against precision (avoiding false alarms). The table below uses illustrative numbers — you will replace them with your own project metrics.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create example model comparison DataFrame: Baseline, LogReg, RandomForest, GBM. Columns: Model, Accuracy, Precision, Recall, F1, ROC AUC, Training Time, Interpretability. Use realistic values. Save to CSV."
# >
# > **After running, verify:**
# > - 4 model rows, 8 columns
# > - Baseline shows lower performance
# > - Best values identifiable per column
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Example model comparison table
model_comparison = pd.DataFrame([
    {
        'Model': 'Baseline (Majority Class)',
        'Accuracy': 0.627,
        'Precision': 0.627,
        'Recall': 1.000,
        'F1 Score': 0.771,
        'ROC AUC': 0.500,
        'Business Impact': 'Current state'
    },
    {
        'Model': 'Logistic Regression',
        'Accuracy': 0.850,
        'Precision': 0.830,
        'Recall': 0.880,
        'F1 Score': 0.854,
        'ROC AUC': 0.910,
        'Business Impact': '+22% accuracy'
    },
    {
        'Model': 'Random Forest',
        'Accuracy': 0.890,
        'Precision': 0.870,
        'Recall': 0.920,
        'F1 Score': 0.894,
        'ROC AUC': 0.945,
        'Business Impact': '+26% accuracy (recommended)'
    },
    {
        'Model': 'Gradient Boosting',
        'Accuracy': 0.885,
        'Precision': 0.865,
        'Recall': 0.915,
        'F1 Score': 0.889,
        'ROC AUC': 0.940,
        'Business Impact': '+26% accuracy'
    }
])

# Function to highlight best values
def highlight_best(s):
    if s.name in ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC']:
        is_best = s == s.max()
        return ['background-color: lightgreen' if v else '' for v in is_best]
    return ['' for _ in s]

# Display styled table
print("=== MODEL COMPARISON TABLE ===")
styled_table = model_comparison.style.apply(highlight_best, axis=0)
display(styled_table)

# Save for use in slides
model_comparison.to_csv('model_comparison.csv', index=False)
print("\n✓ Model comparison saved to model_comparison.csv")

# %% [markdown]
# **Reading the output:**
#
# The styled table shows four models (Baseline, Logistic Regression, Random
# Forest, Gradient Boosting) with accuracy, precision, recall, F1, ROC-AUC,
# and a **Business Impact** column that translates metrics into plain
# language. Cells with the highest value in each metric column are
# highlighted in green, immediately drawing the reader's eye to the
# recommended model.
#
# **Key takeaway:** Always include a human-readable 'Business Impact' column
# so that stakeholders who do not know what ROC-AUC means can still
# understand the comparison.
#
# ---

# %% [markdown]
# ## 5. Speaker Script Template
#
# ### 5.1 Script Structure
#
# **Time allocation for 3-minute video:**
# - Opening (15 seconds): Hook + preview
# - Problem (30 seconds): What and why
# - Approach (30 seconds): How we did it
# - Results (60 seconds): What we found
# - Recommendation (30 seconds): What to do
# - Risks (15 seconds): What to watch
#
# **Script writing tips:**
# - Write like you speak (conversational, not formal)
# - Use short sentences (10-15 words)
# - Avoid jargon or define it immediately
# - Include pauses and transitions
# - Practice out loud and time yourself

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create script_template string with timed sections: Opening (15s), Problem (30s), Approach (30s), Results (45s), Recommendation (30s), Closing (15s). Include placeholders and speaking tips."
# >
# > **After running, verify:**
# > - 6 timed sections totaling \~2-3 minutes
# > - Bracketed placeholders for your content
# > - Speaking tips for tone and delivery
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Script template
script_template = """
=== CONFERENCE VIDEO SCRIPT TEMPLATE ===

[OPENING - 15 seconds]
Hook: [Start with your key finding or a compelling question]
Preview: "Today I'll show you how [brief description of solution and impact]."

[PROBLEM - 30 seconds]
Context: "[Organization/team name] faces [specific problem]."
Impact: "This costs us [quantified impact - money, time, quality]."
Baseline: "Currently, we [describe current approach and its limitations]."

[APPROACH - 30 seconds]
Data: "We analyzed [X samples/records] from [time period and sources]."
Method: "Using [non-technical description of method], we built a model to [predict/classify/recommend]."
Validation: "We tested this on [describe validation approach] to ensure reliability."

[RESULTS - 60 seconds]
Key Finding 1: "We found that [main insight with number]."
  - Supporting detail: "[Specific example or evidence]"
  
Key Finding 2: "Our model achieves [metric] of [percentage], which is [X%] better than baseline."
  - Supporting detail: "[What this means in practice]"
  
Key Finding 3: "The three most important factors are [factor 1], [factor 2], and [factor 3]."
  - Supporting detail: "[Why this matters]"

[RECOMMENDATION - 30 seconds]
Action: "I recommend we [specific action]."
Impact: "This would [expected business outcome with quantification]."
Timeline: "We could pilot this in [timeframe] with [resources needed]."

[RISKS - 15 seconds]
Limitation 1: "We should watch for [specific risk]."
Mitigation: "We'll monitor [specific metrics] and [mitigation strategy]."

[CLOSING - 5 seconds]
Summary: "[Restate key recommendation in one sentence]."
Invitation: "I'm happy to answer questions."

TOTAL TIME: ~3 minutes

=== SCRIPT CHECKLIST ===
□ No jargon or technical terms without explanation
□ All numbers are rounded and meaningful
□ Each section flows logically to the next
□ Script matches slide sequence
□ Timing is realistic (150-180 words per minute)
□ Practiced out loud and timed
□ Includes natural pauses and transitions
"""

print(script_template)

# Save template
with open('script_template.txt', 'w') as f:
    f.write(script_template)
print("\n✓ Script template saved to script_template.txt")

# %% [markdown]
# **Reading the output:**
#
# The script template prints a complete, fill-in-the-blank outline for a **3-minute conference video** broken into six timed sections: Opening (15s), Problem (30s), Approach (30s), Results (60s), Recommendation (30s), and Risks (15s). The Results section gets the most time because it contains the evidence that supports your recommendation — whether that is HomeValue's pricing error reduction or the Health Department's recall improvement.
#
# The checklist at the bottom reminds you to eliminate jargon, round numbers for spoken delivery, and practise out loud. At 150–180 words per minute, a 3-minute video needs 450–540 words total.
#
# **Why this matters:** Most first drafts run long. Having explicit time budgets forces you to cut ruthlessly and prioritise the findings that matter most to your audience. The Health Department's board has 3 minutes of attention — every second of rambling methodology is a second not spent on the recommendation they need to approve.
#
# > **A question that often comes up here:** *"How different is the written script from what I actually say on camera?"* The script is the outline; the recording is the performance. Aim to know the key sentences *word-for-word* (the problem statement, the headline result, the recommendation) and improvise the rest around your slides. Reading the script verbatim comes across as flat; ignoring it entirely leads to rambling. The sweet spot is anchored improvisation — script the landing points, riff the transitions.
#
# ---

# %% [markdown]
# ### 5.2 Gemini Prompts for Script Refinement
#
# Use these prompts to improve your script with Gemini:

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create gemini_prompts dict with 5 templates: Tighten Script, Add Hook, Strengthen Closing, Simplify Technical, Time Check. Print each with header."
# >
# > **After running, verify:**
# > - 5 keys with multi-line prompt templates
# > - Each includes what to paste
# > - Prompts specific enough for useful Gemini feedback
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Gemini prompts for script improvement
gemini_prompts = {
    'Tighten Script': """
    Here is my conference video script:
    
    [PASTE YOUR SCRIPT]
    
    Please help me:
    1. Reduce it to exactly 3 minutes (450-540 words)
    2. Remove any jargon or technical terms
    3. Make sentences shorter and more punchy
    4. Ensure smooth transitions between sections
    5. Add timing markers for each section
    
    Keep the same structure and key findings, just make it more concise and accessible.
    """,
    
    'Convert Findings to Executive Bullets': """
    Here are my technical findings:
    
    [PASTE YOUR FINDINGS]
    
    Please convert these to executive-friendly bullets:
    1. Remove technical jargon
    2. Start each bullet with an action verb or key insight
    3. Include quantified impact where possible
    4. Make each bullet one sentence maximum
    5. Focus on business implications, not methodology
    
    Format as a bulleted list suitable for a slide.
    """,
    
    'Strengthen Headline': """
    Here is my slide headline:
    
    [PASTE YOUR HEADLINE]
    
    Please improve it by:
    1. Making it a complete sentence (subject + verb)
    2. Adding specific numbers or percentages
    3. Focusing on the business outcome, not the method
    4. Keeping it under 15 words
    5. Making it compelling and clear
    
    Give me 3 alternative headlines to choose from.
    """,
    
    'Simplify Methodology': """
    Here is how I describe my methodology:
    
    [PASTE YOUR METHODOLOGY]
    
    Please simplify this for a non-technical executive audience:
    1. Remove statistical and ML terminology
    2. Focus on what we did, not how (conceptually)
    3. Use analogies if helpful
    4. Keep it to 2-3 sentences
    5. Emphasize the validation/credibility aspects
    """,
    
    'Quantify Business Impact': """
    Here are my model performance metrics:
    
    [PASTE YOUR METRICS]
    
    Please help me translate these into business impact:
    1. Convert accuracy/precision/recall to business outcomes
    2. Estimate cost savings or revenue impact
    3. Compare to current baseline in business terms
    4. Make the impact tangible and specific
    5. Include both pessimistic and optimistic scenarios if appropriate
    """
}

print("=== GEMINI PROMPTS FOR SCRIPT REFINEMENT ===")
for prompt_name, prompt_text in gemini_prompts.items():
    print(f"\n{'='*60}")
    print(f"PROMPT: {prompt_name}")
    print('='*60)
    print(prompt_text)

# Save prompts
with open('gemini_prompts.json', 'w') as f:
    json.dump(gemini_prompts, f, indent=2)
print("\n✓ Gemini prompts saved to gemini_prompts.json")

# %% [markdown]
# **Reading the output:**
#
# Five pre-written Gemini prompts are displayed: **Tighten Script**, **Convert Findings to Executive Bullets**, **Strengthen Headline**, **Simplify Methodology**, and **Quantify Business Impact**. Each prompt includes step-by-step constraints so the AI assistant produces targeted edits rather than generic feedback.
#
# For example, the "Quantify Business Impact" prompt asks Gemini to convert precision/recall into business outcomes — "Catching 35% more cancers" or "Reducing pricing error by $20k per valuation." This translation from statistical metrics to stakeholder language is the single most valuable step in narrative preparation.
#
# **Key takeaway:** Structured prompts with clear constraints (e.g., "reduce to 450–540 words", "no unexplained jargon") produce far better AI-assisted edits than vague requests like "make it better." The JSON export makes these prompts reusable across your course project and future presentations.
#
# ---

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 2 (5 minutes)
#
# **Task:** Write a 2-3 minute script aligned to your outline.
#
# **Instructions:**
# 1. Use the script template above as a guide
# 2. Write your script following the time allocations
# 3. Focus on:
#    - Clear, conversational language
#    - Specific numbers and examples
#    - Smooth transitions between sections
#    - Strong opening and closing
# 4. Read it out loud and time yourself
# 5. Revise to fit 2-3 minutes
#
# **Success criteria:**
# - Script is 450-540 words (3 minutes at 150-180 wpm)
# - No unexplained jargon
# - Clear business impact
# - Flows naturally when read aloud
#
# ---

# %% [markdown]
# **Reading the output:**
#
# The visuals checklist lists **eight required visual types**: Model Comparison Table, Performance Metrics Chart, Feature Importance, Confusion Matrix, ROC/PR Curve, Business Impact Chart, Decision Policy, and Monitoring Dashboard. Each row explains the purpose, what it must include, and design tips.
#
# For HomeValue, the Business Impact Chart translates MAE improvement to revenue: "Reducing pricing error by $20,000 across 5,000 annual valuations saves an estimated $X in lost deals and repricing costs." For the Health Department, it translates recall improvement to lives saved: "Improving recall by 11 percentage points across 10,000 annual screenings means approximately 110 additional early cancer detections per year."
#
# **Why this matters:** Stakeholders do not evaluate your model on AUC — they evaluate it on whether your visuals convince them that the investment was worthwhile. This checklist ensures every required perspective is covered.
#
# ---

# %% [markdown]
# ## 6. Video Production Checklist
#
# ### 6.1 Recording Checklist
#
# Recording a conference-style video is often the last deliverable you create, yet it carries disproportionate weight in how your work is perceived. A well-prepared video with clear audio and a tight script can elevate a good project to an excellent one — while a poorly recorded video can undermine weeks of strong technical work. The checklist below covers pre-recording, recording, post-production, and submission so that nothing is left to chance.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create video_checklist DataFrame: Pre-Recording (environment, equipment, script, slides), Recording (delivery, pacing, visuals, audio), Post-Recording (review, editing, export, submission). Save to CSV."
# >
# > **After running, verify:**
# > - Three production phases, 4+ tasks each
# > - Details provide specific instructions
# > - Saved to video_checklist.csv
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Video production checklist
video_checklist = pd.DataFrame([
    {
        'Category': 'Pre-Recording',
        'Task': 'Script finalized and practiced',
        'Status': '□',
        'Notes': 'Read aloud 3-5 times, time yourself'
    },
    {
        'Category': 'Pre-Recording',
        'Task': 'Slides finalized and tested',
        'Status': '□',
        'Notes': 'No animations that could fail, all fonts embedded'
    },
    {
        'Category': 'Pre-Recording',
        'Task': 'Recording environment prepared',
        'Status': '□',
        'Notes': 'Quiet space, good lighting, neutral background'
    },
    {
        'Category': 'Recording',
        'Task': 'Audio quality check',
        'Status': '□',
        'Notes': 'Test recording first, use external mic if possible'
    },
    {
        'Category': 'Recording',
        'Task': 'Video quality check',
        'Status': '□',
        'Notes': 'Minimum 720p, stable camera, eye level'
    },
    {
        'Category': 'Recording',
        'Task': 'Screen share tested',
        'Status': '□',
        'Notes': 'If sharing slides, ensure they are visible'
    },
    {
        'Category': 'Recording',
        'Task': 'Complete run-through recorded',
        'Status': '□',
        'Notes': 'Aim for one take, minor stumbles are okay'
    },
    {
        'Category': 'Post-Recording',
        'Task': 'Trim opening/closing dead air',
        'Status': '□',
        'Notes': 'Keep it tight, start strong'
    },
    {
        'Category': 'Post-Recording',
        'Task': 'Check audio sync',
        'Status': '□',
        'Notes': 'Ensure lips match words'
    },
    {
        'Category': 'Post-Recording',
        'Task': 'Add captions if required',
        'Status': '□',
        'Notes': 'Improves accessibility and clarity'
    },
    {
        'Category': 'Post-Recording',
        'Task': 'Export in required format',
        'Status': '□',
        'Notes': 'MP4 recommended, H.264 codec'
    },
    {
        'Category': 'Submission',
        'Task': 'File size under limit',
        'Status': '□',
        'Notes': 'Check LMS requirements'
    },
    {
        'Category': 'Submission',
        'Task': 'Video uploaded and tested',
        'Status': '□',
        'Notes': 'Watch entire video after upload to verify'
    }
])

print("=== VIDEO PRODUCTION CHECKLIST ===")
print(video_checklist.to_string(index=False))

# Save checklist
video_checklist.to_csv('video_checklist.csv', index=False)
print("\n✓ Video checklist saved to video_checklist.csv")

# %% [markdown]
# **Reading the output:**
#
# The video checklist has **13 tasks** grouped into Pre-Recording, Recording, Post-Recording, and Submission. Pre-Recording ensures your script, slides, and environment are ready (practise 3–5 times, embed all fonts). Recording covers audio quality, video resolution, and screen-share logistics. Post-Recording includes trimming dead air, syncing audio, and exporting in MP4 format. The Submission row reminds you to verify the upload plays correctly before the deadline.
#
# **Why this matters:** Technical glitches — bad audio, missing slides, wrong file format — are entirely avoidable but destroy credibility. Whether you are presenting HomeValue's pricing tool at a conference or the Health Department's screening results to the board, professionalism in the recording reflects professionalism in the analysis.
#
# ---

# %% [markdown]
# ### 6.2 Common Mistakes and How to Avoid Them
#
# **❌ Mistake #1: Reading the slides verbatim**
# - ✓ Fix: Slides = headlines, Script = explanation
#
# **❌ Mistake #2: Too much technical detail**
# - ✓ Fix: Explain what you found, not how you found it
#
# **❌ Mistake #3: Poor audio quality**
# - ✓ Fix: Record in quiet space, use external mic, test first
#
# **❌ Mistake #4: Going over time**
# - ✓ Fix: Practice with timer, cut ruthlessly, prioritize impact
#
# **❌ Mistake #5: No clear recommendation**
# - ✓ Fix: End with specific action + expected impact + timeline
#
# **❌ Mistake #6: Ignoring limitations**
# - ✓ Fix: Address 1-2 key limitations and mitigation strategies
#
# **❌ Mistake #7: Starting too technical**
# - ✓ Fix: Hook with business problem or key finding, not methodology

# %% [markdown]
# ## 7. Final Deliverable Package
#
# ### 7.1 What to Submit
#
# Your final project is not a single file but a coordinated package of artifacts — the same kind of package a consulting firm delivers to a client or a data science team submits for production review. The table below lists each deliverable, its format, and its submission requirements. Whether your project addresses HomeValue's pricing challenge, the Health Department's screening tool, or your own dataset, the deliverable structure is identical.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create deliverable_package DataFrame: Notebook, Slides, Video, Model Artifacts, Monitoring Plan, Model Card. Columns: Deliverable, Description, Format, Where to Submit, Status. Save to CSV."
# >
# > **After running, verify:**
# > - 6 deliverables with format requirements
# > - Specific submission locations
# > - Status checkbox for tracking
# > - All numerical outputs use standard decimal format — no scientific notation

# %% [markdown]
# **Reading the output:**
#
# The styled table shows four models (Baseline, Logistic Regression, Random Forest, Gradient Boosting) with accuracy, precision, recall, F1, ROC-AUC, and a **Business Impact** column that translates metrics into plain language. Cells with the best value in each column are highlighted in green, drawing the reader's eye to the recommended model.
#
# The Business Impact column is what separates a technical comparison from an executive-ready one. "Random Forest: +26% accuracy (recommended)" means the CEO does not need to know what accuracy, precision, or recall mean — she can see that one model is recommended and why.
#
# **Key takeaway:** Always include a human-readable Business Impact column so stakeholders who do not know what ROC-AUC means can still understand the comparison and make an informed decision.
#
# ---

# %% [markdown]
# **Reading the output:**
#
# The deliverable-package table lists **six items**: Jupyter Notebook, Slide Deck, Conference Video, Model Artifacts, Monitoring Plan, and Model Card. Each row specifies the required format, a brief description, and the submission method (Colab link, LMS upload, GitHub repo, etc.).
#
# **Key takeaway:** Treat this table as your final submission manifest. Walk through it one row at a time, tick each checkbox, and verify every link in an incognito browser window before the deadline. A missing deliverable — even a strong one that was simply not uploaded — cannot earn credit.
#
# ---

# %% [markdown]
# ### 7.2 Quality Standards
#
# **Your work will be evaluated on:**
#
# 1. **Technical Rigor (40%)**
#    - Proper methodology and validation
#    - Reproducible pipeline
#    - Appropriate model selection
#    - Statistical soundness
#
# 2. **Communication Clarity (30%)**
#    - Clear problem statement
#    - Logical narrative flow
#    - Effective visuals
#    - Professional presentation
#
# 3. **Business Impact (20%)**
#    - Clear recommendation
#    - Quantified impact
#    - Actionable insights
#    - Risk awareness
#
# 4. **Production Readiness (10%)**
#    - Monitoring plan
#    - Documentation
#    - Reproducibility
#    - Responsible AI considerations

# %% [markdown]
# ## 8. Wrap-Up: Key Takeaways
#
# ### What We Learned Today:
#
# 1. **Five-Act narrative structure.** Problem → Approach → Results → Recommendation → Risks. Every executive-ready story has these five beats. Miss one and the audience leaves with questions.
# 2. **Ten slides, five minutes, one visual per results slide.** The cadence for a research-symposium-style presentation. Longer on dense result slides, faster on transitions; aim for 30 seconds per slide on average.
# 3. **Anchored improvisation, not scripted recitation.** Know the landing sentences word-for-word; improvise the transitions. Reading the script flatline kills the audience; ignoring the script leads to rambling.
# 4. **Audio clarity beats video polish.** Clean audio, quiet room, USB microphone. Webcam quality matters far less. Viewers forgive modest production; they do not forgive crackling audio.
# 5. **The deliverable package is: notebook + slides + 5-minute video + model card.** nb18's reproducible artifacts plus nb17's model card plus today's narrative plus today's video. Five artifacts, one project, one signed-off audit trail.
#
# ### Critical Rules:
#
# > **"Five acts: Problem, Approach, Results, Recommendation, Risks. Miss one, lose the audience."**
#
# > **"One visual per results slide, no pure-text results."**
#
# > **"Audio clarity beats video polish."**
#
# ### Next Steps:
#
# - **nb20 (Final Submission + Peer Review)** is literally tomorrow — run the self-audit, submit the artifact manifest, complete a peer review of a classmate, and write the postmortem.
# - **The Kaggle competition also closes tomorrow.** nb18 showed you the submission mechanics; make sure submission.csv is uploaded well before the 11:59 PM deadline.
#
# > **A question that often comes up here:** *"If I rehearse multiple times, should I memorize the whole script?"* Memorize the landing sentences and the transitions, not the connective tissue. Every time you rehearse, the recording gets smoother — but never sacrifice natural delivery for perfect word-for-word. The judges on the research symposium panel want clarity, not an actor's performance.
#
# ---

# %% [markdown]
# ## Participation Assignment Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Complete all exercises**: Fill in both PAUSE-AND-DO exercise cells with your findings
# 2. **Run All Cells**: Execute `Runtime → Run all` to ensure everything works
# 3. **Save a Copy**: `File → Save a copy in Drive or Download the .ipynb extension`
# 4. **Submit**: Upload your `.ipynb` file in the participation assignment you find in the course Brightspace page.
#
# ### Before Submitting, Check:
#
# - [ ] All cells execute without errors
# - [ ] All outputs are visible
# - [ ] Both exercise responses are complete
# - [ ] Notebook is shared with correct permissions
# - [ ] You can explain every line of code you wrote
#
# ### Next Step:
#
# Complete the **Quiz** in Brightspace (auto-graded)
#
# ---
#
# ## 9. Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Run All Cells**: Execute `Runtime → Run all` to ensure everything works
# 2. **Save a Copy**: `File → Save a copy in Drive`
# 3. **Get Shareable Link**: Click `Share` and set to "Anyone with the link can view"
# 4. **Submit Link**: Paste the link in the LMS assignment
#
# ### Before Submitting, Check:
#
# - [ ] All cells execute without errors
# - [ ] All outputs are visible
# - [ ] Slide outline is complete (10+ slides)
# - [ ] Script is written and timed (2-3 minutes)
# - [ ] Notebook is shared with correct permissions
#
# ### Project Checkpoint:
#
# - [ ] Draft slide outline submitted
# - [ ] Draft script submitted
# - [ ] Visuals checklist completed
#
# ---
#
# ## Bibliography
#
# - Knaflic, C. N. (2015). *Storytelling with Data: A Data Visualization Guide for Business Professionals*. Wiley.
# - Minto, B. (2009). *The Pyramid Principle: Logic in Writing and Thinking*. Pearson Education.
# - Provost, F., & Fawcett, T. (2013). *Data Science for Business: What You Need to Know about Data Mining and Data-Analytic Thinking*. O'Reilly Media. (Chapters on communicating results to stakeholders)
# - Duarte, N. (2008). *slide:ology: The Art and Science of Creating Great Presentations*. O'Reilly Media.
# - Reynolds, G. (2011). *Presentation Zen: Simple Ideas on Presentation Design and Delivery*. New Riders.
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
