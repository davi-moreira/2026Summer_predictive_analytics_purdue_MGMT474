# %% [markdown]
# # Course End and Reflection — Project Package Submission, Peer Review, and Reflection Survey
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/main/notebooks/figures/mgmt_474_ai_logo_02-modified.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>QM47400 Predictive Analytics</center>
# # <center>Professor: Davi Moreira </center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/nb20_final_submission_peer_review.ipynb)
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Deliver a complete end-to-end predictive analytics package
# 2. Produce an executive-ready deck and a conference-style video
# 3. Demonstrate reproducibility (run-all notebook, documented choices)
# 4. Evaluate peers' work using a structured rubric and provide actionable feedback
# 5. Write a concise postmortem: what worked, what didn't, what you'd do next
#
# ---

# %% [markdown]
# ## 1. Setup: Imports and Display Settings
#
# Whether your project targeted HomeValue's pricing tool or the State Health Department's screening programme, the final deliverable must run cleanly from top to bottom in a fresh Colab session. This setup cell loads only lightweight utilities — pandas for the audit checklists, matplotlib/seaborn for any last-minute visual tweaks, and `json` for the artifact manifest. No modelling libraries are needed because this notebook focuses on review, submission logistics, and peer evaluation.

# %% [markdown]
# > **📋 Participation Reminder:** This notebook contains **2 PAUSE-AND-DO exercises**. You are expected to complete all exercises before submitting your notebook.
#
# ---

# %% [markdown]
# ## 💼 Why This Matters: The Professional Deliverable
#
# In industry, no analytics project ships without review. Before the **State Health Department** screening tool report goes to the health department, a colleague reviews your work using a structured rubric: Is the methodology sound? Are the results reproducible? Is the narrative clear? Are limitations acknowledged?
#
# This peer review process catches blind spots, strengthens arguments, and ensures professional quality. It's the same process used at consulting firms, data science teams, and academic journals — and it's the final step before your work represents your professional reputation.
#
# > **Today's focus:** Completing a professional-quality analytics deliverable and conducting a structured peer review that strengthens both your work and your reviewer skills.
#
# > **A question that often comes up here:** *"If my project works in my own notebook, why do I need all this audit ceremony?"* Because "works in my own notebook" is the easiest test case. A reviewer opens your artifact on a different machine, with a different Python version, on a different day — and if it does not run, everything you claimed about its performance is unverifiable. The self-audit checklist is not busywork; it is the exact sequence of checks a real code-review or regulatory-audit pass would run. Passing the audit here is practice for passing audits that matter later.
#
# ---

# %%
# Install required packages (uncomment if needed)
# !pip install pandas numpy matplotlib seaborn --quiet

# Core imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import json
import warnings

# Display settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 3)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

print("✓ Setup complete!")
print(f"Final submission date: {datetime.now().strftime('%Y-%m-%d')}")

# %% [markdown]
# **Reading the output:**
#
# The `Setup complete!` confirmation and timestamp mean every utility needed for auditing, manifest creation, and peer-review scoring is loaded. The printed date anchors your submission — if a grader or reviewer later asks “when was this last run?”, the timestamp answers immediately. No modelling libraries appear because this notebook audits and packages work you already completed in Notebooks 01–19; it does not fit or evaluate any model.
#
# **Key takeaway:** Even an audit-only notebook must execute cleanly top-to-bottom. A submission that fails on its very first cell signals that reproducibility discipline broke down at the finish line — exactly when stakeholders (or graders) are paying the closest attention.
#
# ---

# %% [markdown]
# ## 2. Final Self-Audit Checklist
#
# ### Why Self-Audit?
#
# Before HomeValue's pricing report reaches the CEO or MedScreen's screening results reach the oncology board, someone runs a final quality check. In your case, that someone is you. A systematic self-audit catches the mistakes that cost credibility — a notebook that crashes on Run All, a test set touched too early, a plot with missing axis labels.
#
# > **"Graders check the basics first. If those fail, they may not see your best work."**
# > A thorough self-audit prevents avoidable mistakes that overshadow strong analysis.
#
# ### 2.1 Technical Reproducibility Audit

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create technical_audit DataFrame (\~20 rows): Notebook Execution, Data & Splits, Modeling, Evaluation, Artifacts, Code Quality categories. Columns: Category, Item, How to Check, Status, Priority (CRITICAL/HIGH/MEDIUM). Save to CSV."
# >
# > **After running, verify:**
# > - \~20 rows across 6 categories
# > - Priority levels: CRITICAL, HIGH, MEDIUM
# > - Saved to CSV
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Technical reproducibility checklist
technical_audit = pd.DataFrame([
    {
        'Category': 'Notebook Execution',
        'Item': 'Restart kernel completed',
        'How to Check': 'Runtime → Restart runtime',
        'Status': '□',
        'Priority': 'CRITICAL'
    },
    {
        'Category': 'Notebook Execution',
        'Item': 'Run All completed without errors',
        'How to Check': 'Runtime → Run all (watch for red error messages)',
        'Status': '□',
        'Priority': 'CRITICAL'
    },
    {
        'Category': 'Notebook Execution',
        'Item': 'All outputs visible',
        'How to Check': 'Scroll through entire notebook',
        'Status': '□',
        'Priority': 'CRITICAL'
    },
    {
        'Category': 'Notebook Execution',
        'Item': 'No deprecated warnings (or documented)',
        'How to Check': 'Check for yellow warning messages',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Data & Splits',
        'Item': 'Data source documented',
        'How to Check': 'URL or citation present',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Data & Splits',
        'Item': 'Train/val/test splits clearly labeled',
        'How to Check': 'Variable names and sizes printed',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Data & Splits',
        'Item': 'No test set leakage',
        'How to Check': 'Test set only used in final evaluation',
        'Status': '□',
        'Priority': 'CRITICAL'
    },
    {
        'Category': 'Data & Splits',
        'Item': 'Random seeds documented',
        'How to Check': 'RANDOM_SEED variable defined and used consistently',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Modeling',
        'Item': 'Baseline model included',
        'How to Check': 'Simple baseline (majority class, mean, etc.) reported',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Modeling',
        'Item': 'Multiple models compared',
        'How to Check': 'At least 2-3 different approaches tried',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Modeling',
        'Item': 'Model selection justified',
        'How to Check': 'Clear explanation of why final model was chosen',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Modeling',
        'Item': 'Hyperparameter tuning documented',
        'How to Check': 'Process and results shown',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Evaluation',
        'Item': 'Appropriate metrics chosen',
        'How to Check': 'Metrics match problem type and business goals',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Evaluation',
        'Item': 'Validation strategy documented',
        'How to Check': 'Cross-validation or hold-out clearly explained',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Evaluation',
        'Item': 'Final test set results reported',
        'How to Check': 'Test metrics clearly stated',
        'Status': '□',
        'Priority': 'CRITICAL'
    },
    {
        'Category': 'Artifacts',
        'Item': 'Model saved (joblib or pickle)',
        'How to Check': 'Save/load code present and tested',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Artifacts',
        'Item': 'Configuration saved separately',
        'How to Check': 'CONFIG dict or JSON file',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Code Quality',
        'Item': 'No debug code or TODOs',
        'How to Check': 'Search for "TODO", "FIXME", "print"',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Code Quality',
        'Item': 'Imports organized at top',
        'How to Check': 'All imports in setup cell',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Code Quality',
        'Item': 'Functions have docstrings',
        'How to Check': 'Key functions documented',
        'Status': '□',
        'Priority': 'MEDIUM'
    }
])

print("=== TECHNICAL REPRODUCIBILITY AUDIT ===")
print(technical_audit.to_string(index=False))

# Summary by priority
print("\n=== PRIORITY SUMMARY ===")
priority_counts = technical_audit['Priority'].value_counts()
for priority in ['CRITICAL', 'HIGH', 'MEDIUM']:
    if priority in priority_counts:
        print(f"{priority}: {priority_counts[priority]} items")

# Save audit
technical_audit.to_csv('technical_audit.csv', index=False)
print("\n✓ Technical audit saved to technical_audit.csv")

# %% [markdown]
# **Reading the output:**
#
# The technical audit lists **20 items** across six categories — Notebook Execution, Data & Splits, Modeling, Evaluation, Artifacts, and Code Quality — each with a concrete “How to Check” action and a priority tier. The priority summary at the bottom counts items by tier: **CRITICAL**, **HIGH**, and **MEDIUM**. For a HomeValue project, a CRITICAL failure like test-set leakage means the reported MAE is untrustworthy and the pricing team cannot rely on it. For a MedScreen project, missing a Run-All error means the hospital IT team cannot reproduce your screening model — and regulatory review stops cold.
#
# Focus on clearing every CRITICAL item first. A notebook that cannot Run All is an automatic failure regardless of model sophistication, just as a screening tool that cannot be reproduced is unusable regardless of its AUC.
#
# **Key takeaway:** Treat CRITICAL items as non-negotiable gates. Only move to HIGH and MEDIUM once every CRITICAL checkbox is ticked.
#
# ---

# %% [markdown]
# ### 2.2 Communication Quality Audit
#
# Technical correctness is necessary but not sufficient. HomeValue's CEO will not read your code — she will read your slide headlines, scan your plots, and ask "so what?" The State Health Department's board will judge your screening recommendation by whether the narrative is clear enough to act on. This audit covers the elements that determine whether your analysis *communicates*: logical structure, explanatory markdown, labelled visualisations, and professional polish.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create communication_audit DataFrame (\~15 rows): Structure, Documentation, Visualizations, Tables, Professionalism categories. Columns: Category, Item, How to Check, Status, Priority. Save to CSV."
# >
# > **After running, verify:**
# > - \~15 rows across 5 categories
# > - Each item has 'How to Check' instruction
# > - Saved to CSV
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Communication quality checklist
communication_audit = pd.DataFrame([
    {
        'Category': 'Structure',
        'Item': 'Clear title and introduction',
        'How to Check': 'First cell has project title and context',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Structure',
        'Item': 'Logical section flow',
        'How to Check': 'Sections follow standard order (EDA → Preprocessing → Modeling → Evaluation)',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Structure',
        'Item': 'Summary/conclusion present',
        'How to Check': 'Final section summarizes key findings',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Documentation',
        'Item': 'Markdown cells explain "why"',
        'How to Check': 'Each section has explanation before code',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Documentation',
        'Item': 'Key findings highlighted',
        'How to Check': 'Important results are called out clearly',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Documentation',
        'Item': 'Assumptions stated explicitly',
        'How to Check': 'Key assumptions documented',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Visualizations',
        'Item': 'All plots have titles',
        'How to Check': 'Every visualization has descriptive title',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Visualizations',
        'Item': 'Axes are labeled',
        'How to Check': 'X and Y axes have clear labels',
        'Status': '□',
        'Priority': 'HIGH'
    },
    {
        'Category': 'Visualizations',
        'Item': 'Visualizations support narrative',
        'How to Check': 'Each plot has a purpose and explanation',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Tables',
        'Item': 'Tables are formatted',
        'How to Check': 'DataFrames displayed clearly',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Tables',
        'Item': 'Key values highlighted',
        'How to Check': 'Important numbers are called out',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Professionalism',
        'Item': 'Consistent formatting',
        'How to Check': 'Headers, fonts, spacing consistent throughout',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Professionalism',
        'Item': 'No typos in key sections',
        'How to Check': 'Spell-check title, headers, conclusions',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Professionalism',
        'Item': 'Bibliography included',
        'How to Check': 'References section at end',
        'Status': '□',
        'Priority': 'MEDIUM'
    },
    {
        'Category': 'Professionalism',
        'Item': 'Author and date documented',
        'How to Check': 'Name and date in header',
        'Status': '□',
        'Priority': 'LOW'
    }
])

print("=== COMMUNICATION QUALITY AUDIT ===")
print(communication_audit.to_string(index=False))

# Save audit
communication_audit.to_csv('communication_audit.csv', index=False)
print("\n✓ Communication audit saved to communication_audit.csv")

# %% [markdown]
# **Reading the output:**
#
# The communication audit has **15 items** grouped into Structure, Documentation, Visualizations, Tables, and Professionalism. Unlike the technical audit, most items here are **HIGH** or **MEDIUM** priority because they affect readability rather than correctness. Pay particular attention to the Visualizations section: unlabelled axes and missing titles are the most frequent deductions on presentation-heavy submissions. For a HomeValue deck, a scatter plot of `MedInc` vs. `MedHouseVal` without axis labels forces the pricing team to guess units. For a MedScreen report, an ROC curve without an AUC annotation leaves the oncologist unable to compare your model to the clinical baseline.
#
# **Why this matters:** A reviewer’s first impression is formed by structure and visual polish. A well-documented notebook signals rigour before a single line of code is read — and in a peer review, that first impression anchors every score that follows.
#
# ---

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 1 (5 minutes)
#
# **Task:** Run-all audit and fix one reproducibility issue (real or simulated).
#
# **Instructions:**
# 1. Open your project notebook
# 2. Restart kernel: `Runtime → Restart runtime`
# 3. Run all cells: `Runtime → Run all`
# 4. Watch for errors, warnings, or missing outputs
# 5. If you find an issue, fix it and re-run
# 6. If no issues, simulate one and document how you'd fix it
# 7. Document your findings below
#
# **Common issues to check:**
# - Missing imports
# - Variables used before definition
# - File paths that don't exist
# - Cells that depend on manual execution order
#
# ---

# %% [markdown]
# ### YOUR AUDIT RESULTS HERE:
#
# **Run-all status:**
# [Did all cells execute successfully? Yes/No]
#
# **Issues found:**
# 1. [Describe any errors or warnings]
# 2. [List any missing outputs]
# 3. [Note any other problems]
#
# **Fixes applied:**
# 1. [How you fixed issue #1]
# 2. [How you fixed issue #2]
# 3. [How you fixed issue #3]
#
# **Verification:**
# [Did run-all succeed after fixes? Yes/No]
#
# ---

# %% [markdown]
# ## 3. Submission Links and Artifact Manifest
#
# A complete project deliverable is more than a notebook. Whether your group built HomeValue's pricing model or MedScreen's screening classifier, the audience expects a package: a **research poster** as the public-facing artifact, the runnable notebook that backs every claim on the poster, saved model artifacts, a monitoring plan, and the intra-group peer-evaluation submission. The artifact manifest below catalogues every piece so nothing is forgotten at submission time. The poster itself follows the Brightspace template and is submitted as a single PDF named `<group-number>.pdf` (e.g., `01.pdf`).
#
# ### 3.1 Artifact Manifest Template

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create artifact_manifest nested dict: project_info (title, author, date), deliverables (6 items with format, link, status), validation (5 boolean checks). Pretty-print as JSON, save to file, create DataFrame view."
# >
# > **After running, verify:**
# > - Three top-level keys in JSON
# > - 6 deliverables with format and status
# > - DataFrame checklist view also printed
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# YOUR SOLUTION CODE HERE
# Create artifact_manifest as described in the Gemini prompt above

# %% [markdown]
# **Reading the output:**
#
# The artifact manifest prints as formatted JSON with three top-level keys: project metadata, six deliverables (notebook, slide deck, video, model artifacts, monitoring plan, model card), and five validation flags. The deliverables checklist table below gives a compact, scannable view with a `Submitted` column you can toggle. Each deliverable’s required **format** and **submission method** are specified so there is no ambiguity about what to upload and where.
#
# For a HomeValue project, the “model artifacts” row means the `joblib` pipeline and CONFIG JSON that the pricing team would need to reproduce your predictions in production. For a MedScreen project, it means the calibrated classifier and threshold configuration that a partner hospital would deploy into its EHR system. Missing any single artifact means the package is incomplete and the project cannot move forward.
#
# **Key takeaway:** Before clicking “Submit”, walk through this manifest row by row and test every link in an incognito browser. A broken link is indistinguishable from a missing deliverable.
#
# > **A question that often comes up here:** *"How do I handle artifacts that are too big to commit to git (large datasets, model checkpoints)?"* Store them externally (Google Drive, S3, figshare) and put stable, versioned links in the manifest. Git is for code and small artifacts; large artifacts live elsewhere. The critical discipline is *versioning* — a link to "latest" decays silently; a link to "v3 committed on 2026-06-19" lets a reviewer find exactly what you submitted even if you later iterate.
#
# ---

# %% [markdown]
# ## 4. Peer Review Rubric
#
# ### Why Peer Review?
#
# In industry, no analytics deliverable ships without review. Before HomeValue's pricing report reaches the CEO, a senior analyst reviews the methodology. Before MedScreen's screening tool goes live at a partner hospital, a colleague checks reproducibility and flags blind spots. Peer review catches what self-audit misses — and the reviewer learns as much as the author.
#
# > **"You learn as much from reviewing others' work as from your own."**
# > Good feedback requires critical thinking and makes you a better analyst.
#
# ### 4.1 Review Principles
#
# **Be useful, not nice:**
# - Focus on specific, actionable feedback
# - Point out both strengths and weaknesses
# - Suggest concrete improvements
#
# **Be professional:**
# - Critique the work, not the person
# - Use "I notice" instead of "You did wrong"
# - Balance critical feedback with positive observations
#
# **Be thorough:**
# - Check technical correctness
# - Evaluate communication clarity
# - Consider business relevance — would the CEO or oncologist act on these results?
#
# ### 4.2 Peer Review Rubric

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create review_rubric DataFrame: 5 dimensions (Reproducibility 20%, Methodology 30%, Results 20%, Communication 20%, Responsible AI 10%). Four quality levels with criteria. Save to CSV."
# >
# > **After running, verify:**
# > - 5 dimensions summing to 100%
# > - Four quality levels with specific criteria
# > - Saved to CSV
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Peer review rubric
review_rubric = pd.DataFrame([
    {
        'Dimension': 'Reproducibility',
        'Weight': '20%',
        'Excellent (4)': 'Run-all works perfectly, all outputs visible, fully documented',
        'Good (3)': 'Run-all works with minor issues, most outputs visible',
        'Needs Work (2)': 'Run-all has errors, some outputs missing',
        'Insufficient (1)': 'Cannot run notebook, major errors',
        'Score': ''
    },
    {
        'Dimension': 'Methodology',
        'Weight': '30%',
        'Excellent (4)': 'Sound methods, proper validation, appropriate metrics, no leakage',
        'Good (3)': 'Generally sound with minor issues in validation or metrics',
        'Needs Work (2)': 'Significant methodology gaps or potential leakage',
        'Insufficient (1)': 'Fundamental methodology errors',
        'Score': ''
    },
    {
        'Dimension': 'Results',
        'Weight': '20%',
        'Excellent (4)': 'Clear findings, well-supported, appropriate comparisons',
        'Good (3)': 'Clear findings with minor gaps in support or comparison',
        'Needs Work (2)': 'Unclear findings or weak evidence',
        'Insufficient (1)': 'No clear results or unsupported claims',
        'Score': ''
    },
    {
        'Dimension': 'Communication',
        'Weight': '20%',
        'Excellent (4)': 'Clear narrative, effective visuals, professional presentation',
        'Good (3)': 'Generally clear with minor issues in flow or visuals',
        'Needs Work (2)': 'Unclear narrative or poor visual communication',
        'Insufficient (1)': 'Confusing structure, ineffective communication',
        'Score': ''
    },
    {
        'Dimension': 'Responsible AI',
        'Weight': '10%',
        'Excellent (4)': 'Limitations acknowledged, monitoring plan detailed, risks addressed',
        'Good (3)': 'Basic limitations and monitoring plan present',
        'Needs Work (2)': 'Minimal attention to limitations or risks',
        'Insufficient (1)': 'No consideration of limitations or risks',
        'Score': ''
    }
])

print("=== PEER REVIEW RUBRIC ===")
print(review_rubric.to_string(index=False))

# Save rubric
review_rubric.to_csv('peer_review_rubric.csv', index=False)
print("\n✓ Review rubric saved to peer_review_rubric.csv")

# %% [markdown]
# **Reading the output:**
#
# The peer review rubric defines **five dimensions**: Reproducibility (20%), Methodology (30%), Results (20%), Communication (20%), and Responsible AI (10%). Each dimension has four scoring levels (Excellent 4, Good 3, Needs Work 2, Insufficient 1) with concrete descriptors. **Methodology** carries the highest weight because sound analytical practice is the foundation of a credible project — whether you are pricing houses for HomeValue or screening tumours for the Health Department, a leaky validation strategy invalidates every downstream conclusion.
#
# The **Responsible AI** dimension (10%) explicitly rewards acknowledgement of limitations and monitoring plans. For a MedScreen project, this means documenting fairness across demographic groups and the plan for retraining as population characteristics shift. For a HomeValue project, it means disclosing geographic bias and the risk of stale predictions as housing markets move.
#
# **Why this matters:** Scoring with a rubric removes subjectivity and ensures every reviewer evaluates the same criteria. Use the descriptors to anchor your scores — not gut feeling.
#
# ---

# %% [markdown]
# ### 4.3 Peer Review Form Template
#
# The form below gives you a structured way to record your evaluation. It mirrors the five rubric dimensions and adds space for specific strengths, areas for improvement, and critical issues. Think of it as the report a HomeValue senior analyst would file after reviewing a junior colleague’s pricing model, or the checklist a Health Department reviewer would complete before approving a screening tool for statewide deployment. Filling it out completely ensures that your feedback is both fair and actionable — and that the author knows exactly what to fix.

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create review_form string: Reviewer info, Scores (1-4 scale, 5 dimensions), Detailed Feedback (strengths, improvements), Dimension-Specific Feedback, Additional Comments, Reviewer Reflection. Save to file."
# >
# > **After running, verify:**
# > - Clearly separated sections
# > - Score section has all 5 weighted dimensions
# > - Reflection section prompts learning
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Peer review form template
review_form = """
=== PEER REVIEW FORM ===

Reviewer Name: [Your name]
Project Reviewed: [Project title or author name]
Review Date: [Date]

---

## SCORES (1-4 scale)

Reproducibility (20%):     [ ] / 4
Methodology (30%):          [ ] / 4
Results (20%):              [ ] / 4
Communication (20%):        [ ] / 4
Responsible AI (10%):       [ ] / 4

TOTAL (weighted):           [ ] / 4.0

---

## DETAILED FEEDBACK

### Strengths (What did this project do well?)
1. [Specific strength with example]
2. [Specific strength with example]
3. [Specific strength with example]

### Areas for Improvement (What could be better?)
1. [Specific issue + suggested fix]
2. [Specific issue + suggested fix]
3. [Specific issue + suggested fix]

### Critical Issues (Must fix before production)
1. [Critical issue if any]
2. [Critical issue if any]

---

## DIMENSION-SPECIFIC FEEDBACK

### Reproducibility
- Run-all test: [PASS/FAIL with details]
- Outputs visible: [Yes/No with details]
- Documentation: [Assessment]

### Methodology
- Data splitting: [Assessment]
- Model selection: [Assessment]
- Validation strategy: [Assessment]
- Potential leakage: [Any concerns?]

### Results
- Clarity of findings: [Assessment]
- Evidence quality: [Assessment]
- Baseline comparison: [Present? Appropriate?]

### Communication
- Narrative flow: [Assessment]
- Visual quality: [Assessment]
- Professional presentation: [Assessment]

### Responsible AI
- Limitations acknowledged: [Yes/No with details]
- Monitoring plan: [Present? Adequate?]
- Risk awareness: [Assessment]

---

## ADDITIONAL COMMENTS

[Any other observations, suggestions, or questions]

---

## REVIEWER REFLECTION

What did I learn from reviewing this project?
[Your reflection here]

What will I apply to my own work?
[Your takeaways here]

"""

print(review_form)

# Save form
with open('peer_review_form.txt', 'w') as f:
    f.write(review_form)
print("\n✓ Review form saved to peer_review_form.txt")

# %% [markdown]
# **Reading the output:**
#
# The printed form provides a fill-in-the-blank template with sections for **Scores** (one per rubric dimension), **Detailed Feedback** (strengths, areas for improvement, critical issues), **Dimension-Specific Feedback** (reproducibility, methodology, results, communication, responsible AI), and a **Reviewer Reflection** asking what you learned. The form is also saved as a text file so you can fill it in outside the notebook.
#
# The most valuable section is often the last: **Reviewer Reflection**. Reviewing a peer’s MedScreen model and noticing they included a calibration curve you forgot is the kind of insight that improves your own work. Noticing that a HomeValue project’s slide deck led with MAE before showing the business impact teaches you how narrative order affects persuasion.
#
# **Key takeaway:** Good peer feedback follows the pattern: *Observation + Impact + Suggestion*. Instead of writing “visuals could be better,” write “the ROC curve on slide 6 is missing axis labels and an AUC annotation — adding those would make the visual self-explanatory for the oncology board.”
#
# ---

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 2 (5 minutes)
#
# **Task:** Complete one peer review with rubric scores + 3 actionable edits.
#
# **Instructions:**
# 1. Review the assigned project (or use a sample project)
# 2. Score each dimension (1-4) using the rubric
# 3. Identify 3 specific, actionable improvements
# 4. Complete the review form below
# 5. Focus on being helpful and constructive
#
# **Review guidelines:**
# - Spend \~2 minutes per dimension
# - First check if notebook runs (critical)
# - Then evaluate methodology and results
# - Finally assess communication and responsibility
#
# ---

# %% [markdown]
# ### YOUR PEER REVIEW HERE:
#
# **Project reviewed:** [Title/Author]
#
# **Scores:**
# - Reproducibility: [ ] / 4
# - Methodology: [ ] / 4
# - Results: [ ] / 4
# - Communication: [ ] / 4
# - Responsible AI: [ ] / 4
#
# **Three Actionable Improvements:**
#
# 1. **[Specific issue]**
#    - Current state: [What you observed]
#    - Suggested fix: [Concrete action to take]
#    - Expected improvement: [How this would help]
#
# 2. **[Specific issue]**
#    - Current state:
#    - Suggested fix:
#    - Expected improvement:
#
# 3. **[Specific issue]**
#    - Current state:
#    - Suggested fix:
#    - Expected improvement:
#
# **Overall assessment:**
# [1-2 sentences summarizing the project's main strength and main area for improvement]
#
# ---

# %% [markdown]
# ## 5. Postmortem Prompts
#
# ### Why Write a Postmortem?
#
# At HomeValue, every major model release ends with a retrospective: what drove the biggest accuracy gains? What wasted time? What would you do differently with a second dataset? At the Health Department, deployment reviews ask similar questions before the next screening cycle. A postmortem turns four weeks of hands-on work into durable lessons you can articulate in a job interview or apply to your next project.
#
# > **“Reflection turns experience into learning.”**
# > A postmortem helps you articulate what you learned and what you’d do differently.
#
# ### 5.1 Postmortem Template

# %% [markdown]
# > 💡 **Gemini Prompt:** "Create postmortem_template string: What Worked, What Didn't, Key Learnings, Do Differently, Technical Skills, Business Skills, More Time, Surprising Finding, Valuable Resource, Advice, Next Steps. Save to file."
# >
# > **After running, verify:**
# > - 11 labeled sections with prompts
# > - Example entries to guide responses
# > - Saved to text file
# > - All numerical outputs use standard decimal format — no scientific notation

# %%
# Postmortem template
postmortem_template = """
=== PROJECT POSTMORTEM ===

Project: [Your project title]
Author: [Your name]
Date: [Completion date]

---

## WHAT WORKED WELL (3-5 items)

1. [Specific aspect that went well and why]
   Example: "EDA was thorough and caught a data quality issue early"

2. [Specific aspect that went well and why]

3. [Specific aspect that went well and why]

---

## WHAT DIDN'T WORK (3-5 items)

1. [Specific challenge and why it was difficult]
   Example: "Feature engineering took longer than expected due to unclear documentation"

2. [Specific challenge and why it was difficult]

3. [Specific challenge and why it was difficult]

---

## KEY LEARNINGS (3-5 items)

1. [Specific lesson learned]
   Example: "Always check for data leakage before modeling, not after"

2. [Specific lesson learned]

3. [Specific lesson learned]

---

## WHAT I'D DO DIFFERENTLY NEXT TIME (3-5 items)

1. [Specific change you'd make]
   Example: "Start with simpler models and iterate, rather than jumping to complex models"

2. [Specific change you'd make]

3. [Specific change you'd make]

---

## TECHNICAL SKILLS DEVELOPED

- [Skill 1: e.g., "Cross-validation with stratified folds"]
- [Skill 2: e.g., "Feature importance interpretation"]
- [Skill 3: e.g., "Model deployment with joblib"]
- [Skill 4]
- [Skill 5]

---

## BUSINESS SKILLS DEVELOPED

- [Skill 1: e.g., "Translating technical metrics to business impact"]
- [Skill 2: e.g., "Communicating limitations to stakeholders"]
- [Skill 3: e.g., "Designing monitoring plans for production"]

---

## IF I HAD MORE TIME, I WOULD...

1. [Extension or improvement]
2. [Extension or improvement]
3. [Extension or improvement]

---

## MOST SURPRISING FINDING

[What unexpected insight did you discover?]

---

## MOST VALUABLE COURSE RESOURCE

[Which reading, video, or exercise was most helpful?]

---

## ADVICE FOR FUTURE STUDENTS

[What would you tell someone starting this project?]

---

## NEXT STEPS

[What would you do to continue this project or apply these skills?]

"""

print(postmortem_template)

# Save template
with open('postmortem_template.txt', 'w') as f:
    f.write(postmortem_template)
print("\n✓ Postmortem template saved to postmortem_template.txt")

# %% [markdown]
# **Reading the output:**
#
# The postmortem template prints eleven reflection sections: What Worked Well, What Didn’t Work, Key Learnings, What I’d Do Differently, Technical Skills Developed, Business Skills Developed, If I Had More Time, Most Surprising Finding, Most Valuable Resource, Advice for Future Students, and Next Steps. Each section asks for 3–5 specific, evidence-based items rather than vague generalities — “I learned that `ColumnTransformer` prevents leakage between numeric and categorical pipelines” is useful; “I learned about preprocessing” is not.
#
# **Why this matters:** Research on metacognition shows that structured reflection significantly improves long-term retention of both technical and process skills. A practitioner who can articulate *why* their HomeValue model’s RMSE improved after adding interaction terms — or *why* their MedScreen recall dropped after aggressive feature selection — is the one who carries that lesson into the next project.
#
# ---

# %% [markdown]
# ### 5.2 Your Project Postmortem
#
# Take 10–15 minutes to complete your postmortem below. Be specific: name the features, metrics, tools, and decisions that mattered most. Whether you built HomeValue’s pricing pipeline or MedScreen’s screening classifier, the goal is the same — capture what you would tell a colleague (or your future self) before starting a similar project.

# %% [markdown]
# ### YOUR POSTMORTEM HERE:
#
# **What worked well:**
# 1. [Item 1]
# 2. [Item 2]
# 3. [Item 3]
#
# **What didn't work:**
# 1. [Item 1]
# 2. [Item 2]
# 3. [Item 3]
#
# **Key learnings:**
# 1. [Learning 1]
# 2. [Learning 2]
# 3. [Learning 3]
#
# **What I'd do differently:**
# 1. [Change 1]
# 2. [Change 2]
# 3. [Change 3]
#
# **Most surprising finding:**
# [Your answer]
#
# **Advice for future students:**
# [Your advice]
#
# ---

# %% [markdown]
# ## 6. Wrap-Up: Key Takeaways (and Course Closeout)
#
# ### What We Learned Today:
#
# 1. **Self-audit before submitting — every time.** Restart the kernel, run all, check the manifest, re-read the output. Five minutes of self-audit catches most of what a reviewer would flag in the first ten minutes of review.
# 2. **The artifact manifest is the index to everything.** Links to the notebook, the slides, the video, the model card, the submission.csv — one document, every artifact. A reviewer who cannot find your submission in 30 seconds has already started grading down.
# 3. **Peer review is specific or it is useless.** Three concrete strengths, three concrete suggestions, no vague "analysis seems shallow." The 3-and-3 structure improves the work without damaging the relationship.
# 4. **Postmortems are honest or they are worthless.** "Here's what I got wrong and what I'd do differently" is the one-sentence posture. A postmortem that claims nothing went wrong is read as either dishonest or un-reflective — both worse than admitting mistakes.
# 5. **The course arc is done.** nb01 taught you to split. nb08 taught you to trust the split with a CI. nb09 taught you to run the CV ritual across hyperparameters. nb11–nb13 added tree-based models. nb14 opened the locked test set. nb15–nb17 added interpretation, calibration, and fairness. nb18 made it reproducible. nb19 turned it into a story. Today ties the bow.
#
# ### Critical Rules (the ones that carry out of this course):
#
# > **"Never trust a single split — CV with 95% CI, every time."**
#
# > **"Overlapping CIs mean no winner — pick the simpler model."**
#
# > **"If a preprocessing step uses any data statistic, it belongs inside the Pipeline."**
#
# > **"Slice metrics by group — always, every time, no exceptions."**
#
# > **"Discrimination and calibration are different questions — report both."**
#
# > **"Reproducibility, monitoring, and documentation are not optional; they are the job."**
#
# ### Thank You and What's Next:
#
# This course has tried to build not just technical competence but professional posture — the habits of mind that separate "I fit a model" from "I shipped a model responsibly." Carry forward:
#
# - **The CI-overlap rule** as the decision primitive for every model comparison you make after this course.
# - **The leakage-detection reflex** as the first check when a CV score looks suspiciously good.
# - **The model card discipline** as the artifact that any consequential model deserves.
# - **The postmortem honesty** as the way to grow from each project rather than glossing it over.
#
# > **A question that often comes up here:** *"What if I take another predictive-analytics course next semester and the habits disagree?"* Hold onto the CI-overlap rule, the leakage-detection reflex, and the model-card discipline — those transcend any single course's conventions. Specifics like `RANDOM_SEED = 474` or our particular 60/20/20 split are course-local. The habits are portable.
#
# Congratulations on finishing. Ship the deliverable, submit the Kaggle entry, complete the peer review, write the postmortem honestly — and thank you for the semester.
#
# ---

# %% [markdown]
# ## Participation Assignment Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Complete all exercises**: Fill in both PAUSE-AND-DO exercise cells with your findings
# 2. **Run All Cells**: Execute `Runtime → Run all` to ensure everything works
# 3. **Save a Copy**: `File → Save a copy in Drive or Download the .ipynb extension`
# 4. **Submit**: Upload your `.ipynb` file in the participation assignment you find in the course Brightspace page.
#
# ### Before Submitting, Check:
#
# - [ ] All cells execute without errors
# - [ ] All outputs are visible
# - [ ] Both exercise responses are complete
# - [ ] Notebook is shared with correct permissions
# - [ ] You can explain every line of code you wrote
#
# ### Next Step:
#
# Complete the **Quiz** in Brightspace (auto-graded)
#
# ---
#
# ## 7. Final Project Submission Instructions (Milestone 04)
#
# The Final Project Milestone 04 has **two submission tracks** — the **group-level research poster** and each member's **individual peer evaluation form**. Full instructions: `_final_project/2026Summer/milestone_04_final_poster.md`.
#
# ### Track A — Group Research Poster
#
# 1. **Build the poster** using the Brightspace template (Purdue Undergraduate Research Conference format).
# 2. **Self-audit**: complete both the technical and communication checklists above.
# 3. **Test reproducibility**: link the poster to a working notebook/Colab, then run-all in a fresh kernel.
# 4. **Save as a single PDF** named `<group-number>.pdf` — e.g., Group 01 submits `01.pdf`; Group 17 submits `17.pdf`. **Do not include the section number** in the filename. (This convention is what allows the instructor to print the posters for free.)
# 5. **Submit on Brightspace** under Module 4, Final Project Milestone 04 — Poster.
#
# ### Track B — Individual Peer Evaluation Form
#
# Each group member submits **one** confidential peer-evaluation form covering the **other three teammates** (no self-evaluation).
#
# The form (Brightspace, Module 4) collects, per teammate:
# - 1–5 ratings on: commitment, technical contribution, communication, dependability, fairness of work distribution
# - One specific strength
# - One specific area for improvement
#
# Plus one overall comment about how the group functioned.
#
# > **Failure to submit a peer evaluation reduces the submitter's own peer-evaluation score (not the teammates').**
#
# ### Optional: Fall 2026 Conference Presentation
#
# Groups choosing to present at the **Fall 2026 Purdue Undergraduate Research Conference** are encouraged to email Professor Moreira early (ideally before M3) so mentorship and conference-specific guidance can be arranged. Conference details: <https://www.purdue.edu/undergrad-research/conferences/index.php>
#
# Presenting is **optional** and has no impact on the course grade.
#
# ### Final Checklist:
#
# **Group deliverables (REQUIRED):**
# - [ ] Research poster as a single PDF named `<group-number>.pdf`
# - [ ] Supporting Jupyter notebook (run-all complete; link visible on poster)
# - [ ] Saved model artifacts (joblib + CONFIG JSON, accessible via the link)
# - [ ] Monitoring plan (documented in the supporting notebook or appendix)
#
# **Individual deliverable (REQUIRED — one per group member):**
# - [ ] Peer-evaluation form completed (3 teammates rated; comments filled in)
#
# **Recommended:**
# - [ ] Postmortem written (what worked / didn't / key learnings / what we'd do differently)
#
# ### Before You Click Submit:
#
# - [ ] Poster PDF named exactly `<group-number>.pdf`
# - [ ] All links on the poster tested in incognito/private browser
# - [ ] Group submission AND every individual peer-evaluation submitted
# - [ ] Deadline confirmed in Brightspace
# - [ ] Backup copies saved
#
# ---
#
# ## Bibliography
#
# ### Core References
#
# - Mitchell, M., Wu, S., Zaldivar, A., Barnes, P., Vasserman, L., Hutchinson, B., Spitzer, E., Raji, I. D., & Gebru, T. (2019). Model Cards for Model Reporting. *Proceedings of the Conference on Fairness, Accountability, and Transparency*.
# - Huyen, C. (2022). *Designing Machine Learning Systems*. O'Reilly Media. (Chapters on deployment checklists and monitoring)
# - Knaflic, C. N. (2015). *Storytelling with Data: A Data Visualization Guide for Business Professionals*. Wiley.
# - Minto, B. (2009). *The Pyramid Principle: Logic in Writing and Thinking*. Pearson Education.
#
# ### Additional Resources
#
# - Provost, F., & Fawcett, T. (2013). *Data Science for Business*. O'Reilly Media.
# - James, G., Witten, D., Hastie, T., & Tibshirani, R. (2021). *An Introduction to Statistical Learning with Python*. Springer.
# - Lakshmanan, V., Robinson, S., & Munn, M. (2020). *Machine Learning Design Patterns*. O'Reilly Media.
# - scikit-learn User Guide: [Model persistence](https://scikit-learn.org/stable/model_persistence.html)
# - Google: [People + AI Guidebook](https://pair.withgoogle.com/guidebook)
# - Award-winning prior posters from this course: <https://davi-moreira.github.io/applied_projects.html>
#
# ---
#
# ## Thank You!
#
# Congratulations on completing the Predictive Analytics course!
#
# Your group has built a complete end-to-end ML project from problem framing through a public-facing research poster. This is a significant accomplishment that demonstrates both technical skill and professional judgment.
#
# **Remember:**
# - Keep learning and experimenting
# - Share your work with others
# - Ask questions and seek feedback
# - Apply these skills to real-world problems
#
# **Good luck with your data science journey!**
#
# ---

# %% [markdown]
# ## 5. Reflection Survey — Required for Course Closeout
#
# The final asynchronous deliverable is a short **reflection survey** (10–15 minutes). Your honest, specific responses become the seed for next year's course redesign. The survey is anonymous in aggregate and **required for completion** — submission status is tracked separately from M4 and the Kaggle competition.
#
# The survey covers four areas:
#
# 1. **What worked** — which notebook, exercise, or topic was the highest-leverage learning moment for you, and why?
# 2. **What did not work** — the one thing you would cut, change, or add. Be specific (cell number, video segment, or notebook section).
# 3. **Career relevance** — name one analyst, consultant, or PM task you now feel measurably more equipped for, and one you still feel underprepared for.
# 4. **Open feedback** — anything else Professor Moreira and the AI assistant should know before redesigning for next summer.
#
# **Submit by 11:59 PM (Day 20)** via the Brightspace survey link (also pinned in the course Slack `#announcements` channel). The survey takes 10–15 minutes and is required to mark the course complete.
#
# > **A question that often comes up here:** *"Will my answers affect my grade?"* No. The survey is collected separately from grading and is read only by Professor Moreira and the AI assistant for course redesign. The point is candor, not performance — be specific where you can be specific, and skip questions you do not have a strong opinion on.

# %% [markdown]
# ### 📝 PAUSE-AND-DO Exercise — Pre-survey Reflection (5 minutes)
#
# Before opening the survey link, jot down a one-line answer to each of the four areas above. This makes the actual survey response specific and useful.
#
# ### YOUR REFLECTION SEEDS HERE:
#
# 1. **Highest-leverage moment:** *[notebook / exercise / video — one sentence why]*
# 2. **One thing to change:** *[specific cell / video / section — one sentence]*
# 3. **More equipped for:** *[task]*  |  **Still underprepared for:** *[task]*
# 4. **Other feedback:** *[one sentence]*

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
