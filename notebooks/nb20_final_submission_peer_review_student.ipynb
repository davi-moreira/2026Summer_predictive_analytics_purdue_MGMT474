# %% [markdown]
# # Final Project Milestone 04 Walkthrough — Research Poster, Kaggle Final Submission, and Course Reflection
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/main/notebooks/figures/mgmt_474_ai_logo_02-modified.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>QM47400 Predictive Analytics</center>
# # <center>Professor: Davi Moreira </center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/nb20_final_submission_peer_review_student.ipynb)
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this walkthrough you should be able to:
#
# 1. Explain what your group delivers at **Final Project Milestone 04** — a conference-style research **poster** (`NN.pdf`) and the runnable final notebook (`NN_final.ipynb`) that backs every number on it.
# 2. Run the **one-shot test-set evaluation** correctly: open the locked test set exactly once with your saved M3 champion, and report the **INSIDE / ABOVE / BELOW** verdict against the M3 cross-validation confidence interval.
# 3. Read the **M4 poster rubric** (100 points across seven criteria, plus a -10 filename penalty) and self-check your poster before you submit.
# 4. Ship your group's **Course Case Competition (Kaggle Bank Churn)** final submission and the `NN_kaggle_code.ipynb` notebook, using the same CI-first discipline.
# 5. Complete the two individual closeouts: the confidential **peer evaluation** and the required **course reflection survey**.
#
# ---

# %% [markdown]
# > **📋 Submission Reminder:** Milestone 04 has **two group files** (`NN.pdf` + `NN_final.ipynb`) due on the date posted on Brightspace, plus **two individual closeouts** — the confidential peer evaluation and the course reflection survey. One designated group member uploads the two group files on behalf of the whole team. Watch the filename: the rubric carries a **-10 point penalty** for files that don't follow the `NN.pdf` / `NN_final.ipynb` convention.
#
# ## 💼 Why This Matters
#
# Every milestone so far has been a rehearsal for this one. M1 framed the question, M2 shipped a baseline with a 95% confidence interval, and M3 crowned a champion and drafted the abstract. **M4 is delivery day** — when the work becomes a single artifact a stranger can read in five minutes, backed by a notebook a grader can run end to end without you in the room.
#
# It is also the day you finally **open the locked test set**. Since nb01 your group has selected every model on cross-validation and kept the test set sealed; M4 is the one authorized opening of that box, and the number it gives you goes straight onto the poster — INSIDE, ABOVE, or BELOW the cross-validated expectation. That single honest number is what separates a credible result from a hopeful one.
#
# This walkthrough is **markdown only** — there is no new code to run. It is a map of exactly what M4 asks for, in the order the rubric grades it, plus the two parallel closeouts — the Kaggle final submission and the course reflection survey — that mark QM47400 complete.
#
# ---

# %% [markdown]
# ## 1. About the Final Project
#
# The Final Project is your group's **capstone** — four people, four milestones (M1 → M4), one research poster at the end. It is worth **35% of your overall course grade**, broken down as:
#
# - **Milestone deliverables — 40%** of the project grade. Averaged across M1–M4. Graded for clarity, completeness, and on-time submission. M4's two files feed this average.
# - **Peer evaluation — 20%** of the project grade. Each member submits a confidential rating of their teammates through a separate Brightspace form at the end of the course (see §8).
# - **Instructor / TA evaluation — 40%** of the project grade. Your final **poster**, scored against the 100-point rubric in §6.
#
# So Milestone 04 touches **two** of these at once: the poster is the 40% instructor/TA evaluation, and submitting both M4 files on time feeds the 40% milestone average.
#
# If your project turns out well, you're strongly encouraged (but not required) to present it at the **Summer/Fall Purdue Undergraduate Research Conference** — Professor Moreira is happy to serve as your faculty mentor. Award-winning posters from past cohorts of this course live here: <https://davi-moreira.github.io/applied_projects.html>.
#
# The sections below walk Milestone 04 in the same order the rubric grades it.
#
# ---

# %% [markdown]
# ## 2. What to Submit at Milestone 04
#
# Your group submits **two files** on Brightspace by the posted deadline. One designated member uploads on behalf of the whole team.
#
# | # | File | What's inside |
# |---|---|---|
# | 1 | **`NN.pdf`** *(e.g., Group 01 submits `01.pdf`; Group 17 submits `17.pdf`)* | A single PDF **poster** in Purdue Undergraduate Research Conference format, built from the template attached to the Brightspace assignment. **Do not put the section number in the filename** — that convention is what lets every poster be printed for free. |
# | 2 | **`NN_final.ipynb`** *(e.g., for group 03, `03_final.ipynb`)* | The final notebook with the runnable code. It must complete a fresh **Runtime → Run All** in Colab with no errors, and must include the one-shot test-set evaluation from §5 plus all the code behind the poster's figures. |
#
# Detailed format requirements (poster dimensions, the attached template, exact Brightspace location) and the full rubric are posted on Brightspace; the rubric is also reproduced in §6.
#
# ---

# %% [markdown]
# ## 3. The Poster — Required Components
#
# A standout poster reads in roughly five minutes. Yours must carry, in a logical Intro → Methods → Results → Conclusions flow:
#
# 1. **Project title** — concise and informative. *If your project uses a synthetic generated dataset, the title must say so.*
# 2. **Group members + section.**
# 3. **Prediction problem** — framed as a question with a question mark (e.g., *"Can six-month customer-churn risk be predicted from transaction history?"*).
# 4. **Motivation and significance** — why this prediction matters.
# 5. **Data overview** — source, size, key variables, and the response-variable type.
# 6. **Methodology** — the leakage-safe preprocessing pipeline (`ColumnTransformer` + `StandardScaler` + `OneHotEncoder`), feature engineering, the M2 baseline and the M3 complex model, the cross-validation protocol, and the hyperparameter search.
# 7. **Results — including the one-shot test-set evaluation (required; see §5)** — the M3 champion's CV mean ± 95% CI, the test-set metric opened exactly once, and the INSIDE / ABOVE / BELOW verdict.
# 8. **Interpretation and insights** — feature importance or coefficients, and what they say about the business question.
# 9. **Limitations + next steps** — honest about what the data can and cannot support.
# 10. **References** — datasets, papers, external resources. (The submitted `NN_final.ipynb` is your canonical reproducibility artifact; no separate code-repository link is required on the poster.)
#
# ---

# %% [markdown]
# ## 4. Required Visualizations on the Poster
#
# A great poster carries **4–6 high-information figures, not 12 mediocre ones**. Every figure needs axis labels, units where they apply, a clear legend, and a one-sentence caption that names the takeaway. The following figures are **required** (omitting any of them costs rubric points under Visual Design and Results):
#
# - **Model-comparison bar chart** — the M2 baseline vs. the M3 champion (and any further-tuned variant), each as a bar with **95% Student's *t* CI error bars**. This is the figure that visually justifies your CI-overlap-rule decision.
# - **Test-set verdict figure** — the test metric overlaid on the M3 CV CI bar, picturing the INSIDE / ABOVE / BELOW verdict from §5.
# - **Feature-importance / coefficient plot** — a horizontal bar chart of the champion's top features (signed coefficients for linear/logistic models; permutation or impurity importance for tree-based models).
# - **For regression projects** — a predicted-vs-actual scatter with the 45° reference line, OR a residual plot with a `y = 0` reference line.
# - **For classification projects** — a confusion matrix at your operating threshold AND a ROC curve with AUC, OR a Precision–Recall curve with PR-AUC (lead with PR if the positive class is rare).
#
# If a figure tells the same story as one already on the poster, replace it — every figure should add information.
#
# ---

# %% [markdown]
# ## 5. The One-Shot Test-Set Evaluation (the lockbox ceremony)
#
# This is the single most important — and most easily botched — step of Milestone 04. Since nb01 your group has kept its test set in a **lockbox**: M1 framed the question, M2 and M3 selected models entirely on **cross-validation**, and the test set was never touched. M4 is the **one and only** authorized opening of that box.
#
# The ceremony has exactly four moves:
#
# 1. **Reload the champion you saved at M3.** Use the `champion_pipeline.joblib` from your M3 final-training step (retrained on the full training fold). Do **not** re-tune anything here.
# 2. **Open the locked test set once.** Compute the champion's metric — RMSE/MAE/R² for regression, ROC-AUC/F1 for classification — on the held-out test set. A single evaluation.
# 3. **Render the verdict against the M3 CV 95% confidence interval:**
#    - **INSIDE** — the test number falls within the M3 cross-validation CI. The model generalized exactly as the CV predicted. This is the outcome you want.
#    - **BELOW** — the test number is *better* than the CV expected (lower error, or higher score). Pleasant, but report it plainly rather than celebrating.
#    - **ABOVE** — the test number is *worse* than the CV upper bound. The model underperformed its CV estimate; add a one-sentence diagnosis and a clear **deploy / pause / re-train** recommendation.
# 4. **Report it on the poster and in `NN_final.ipynb`** — the test metric, the CV CI, and the verdict, side by side (this is the test-set verdict figure from §4).
#
# > **A question that often comes up here:** *"Our test number came out ABOVE the CV interval — can we just tune a bit more and re-open the test set?"* No. The moment you select anything against the test set, it stops being a held-out exam and the lockbox discipline that carried through M1 → M2 → M3 is gone — and graders can usually see it in the notebook's cell history. An ABOVE verdict is not a failed project; it is an **honest, reportable finding**. State the gap, give a one-sentence diagnosis (overfitting, distribution shift, an unlucky small test split), and make a deploy/pause/re-train call. A team that reports an honest miss with a recommendation scores better than a team that quietly re-opened the box to make the number look good.
#
# ---

# %% [markdown]
# ## 6. The Milestone 04 Poster Rubric (100 points)
#
# The poster drives the **40% Instructor/TA Evaluation** of your project grade. It is scored on a 100-point scale across seven criteria. Use this table to self-check before you submit.
#
# | # | Criterion | Points | What full marks look like |
# |---|---|---:|---|
# | 1 | Prediction Goal(s) | 5 | Clear, specific objective; response type (regression/classification) named and justified with a business rationale. |
# | 2 | Dataset Overview | 8 | Number of observations and features, types for key features, response variable identified, data provenance/window stated. |
# | 3 | Exploratory Data Analysis | 12 | Summaries of the response and key predictors, at least two relevant plots, interpretation of skew/outliers/imbalance, linked to modeling choices. |
# | 4 | Data Preparation | 20 | At least one non-trivial engineered feature with rationale; missingness quantified and handled leakage-safe; impact shown via CV deltas. |
# | 5 | Baseline Model | 20 | Appropriate simple baseline; leakage-safe pipeline; k = 5 or 10 CV with the correct metric; mean/variance reported; limitations noted. |
# | 6 | More Complex Model | 25 | Model aligned to the goal; hyperparameter search inside proper CV; leakage controls; rigorous comparison to the baseline. |
# | 7 | Report Quality & Visual Communication | 10 | Scannable layout; legible, labeled figures; consistent typography; clean Intro→Methods→Results→Conclusions flow; minimal grammar issues. |
#
# **Total: 100 points.** A filename that does not follow the `NN.pdf` / `NN_final.ipynb` convention costs **-10 points** — easy points to keep.
#
# ---

# %% [markdown]
# ## 7. Course Case Competition — Final Kaggle Submission
#
# The **Course Case Competition (Kaggle Bank Churn)** runs in parallel with the Final Project and uses the **same CI-first workflow** you built for M3. At course close your group locks in its final Kaggle submission and turns in one notebook.
#
# **The task.** For each customer in the test set, predict the **probability of churn** (`Exited = 1`). Submissions are scored by **ROC-AUC**. The **public** leaderboard scores a fraction of the test set during the competition; the **private** leaderboard — revealed at the close — is what grades you.
#
# **What to submit.**
#
# - **On Kaggle:** your team's final submission `.csv` — two columns (`id`, `Exited`), every test row covered, probabilities in [0, 1].
# - **On Brightspace:** **`NN_kaggle_code.ipynb`** — the fully replicable Colab notebook for your best model (loading → preprocessing → feature engineering → tuning → final fit → writing the submission file). One member uploads for the team. A filename that doesn't follow the `NN_kaggle_code.ipynb` convention costs **-10 points**.
#
# **The rules that quietly cost teams grades:**
#
# - **Name your Kaggle team exactly `Group NN`** (with the leading zero, e.g., `Group 03`) so standings map back to the gradebook. Form the team **before anyone submits**.
# - A team of four **shares 5 submissions per day** — not 5 each. Spend them on experiments that actually teach you something.
# - **Do not chase the public leaderboard.** Pick your final submission on the most defensible **cross-validated AUC**, not the highest public score. Models that overfit the public split routinely drop 10+ ranks when the private leaderboard appears.
#
# > **A question that often comes up here:** *"The public leaderboard likes our heavily-tuned model more than our cross-validated pick — which do we ship?"* Ship the cross-validated pick. The public leaderboard is only a fraction of the test set, and tuning against it is selection on the test set — the same leakage trap the whole course has trained you to avoid. Use the public score as a sanity check that nothing is badly broken, then trust your CV confidence interval. The worked starter pipeline from **nb18** walks the full pattern end to end on this dataset.
#
# ---

# %% [markdown]
# ## 8. Course Closeout — Peer Evaluation and Reflection Survey
#
# Two individual deliverables mark the course complete. Both are submitted by **each of you individually** (not one per group), in the last Brightspace module.
#
# ### 8.1 Confidential peer evaluation (20% of the project grade)
#
# Each member submits a **confidential intra-group rating** of their teammates through a separate Brightspace form. It is read only by Professor Moreira and the TA, and it exists to make sure credit follows contribution. Rate honestly and specifically — a vague "everyone was great" helps no one, least of all a teammate who genuinely carried weight.
#
# ### 8.2 Course reflection survey (required for closeout)
#
# The final asynchronous deliverable is a short **reflection survey** (\~10–15 minutes). Your honest, specific answers seed next year's course redesign. It is collected **separately from grading** and covers four areas:
#
# 1. **What worked** — the single highest-leverage notebook, exercise, or topic for you, and why.
# 2. **What didn't** — the one thing you'd cut, change, or add; be specific (a cell, a video segment, a notebook section).
# 3. **Career relevance** — one analyst/consultant/PM task you now feel measurably more equipped for, and one you still feel underprepared for.
# 4. **Open feedback** — anything else the teaching team should know before redesigning for next summer.
#
# > **A question that often comes up here:** *"Will my survey answers affect my grade?"* No. The survey is collected separately from grading and read only for course redesign — the point is candor, not performance. Be specific where you have a strong opinion, and skip what you don't.
#
# Submit both by the deadline posted on Brightspace.
#
# ---

# %% [markdown]
# ## 9. Tips and Common Pitfalls
#
# - **Open the test set ONCE.** The champion was chosen on CV at M3. Compute the test number exactly once with the saved `champion_pipeline.joblib`, report it with the INSIDE / ABOVE / BELOW verdict, and never re-open the box to "recover" a number.
# - **An honest miss beats a hidden one.** An ABOVE verdict with a one-sentence diagnosis and a deploy/pause/re-train call scores better than a suspiciously perfect number.
# - **Show the CV CI on every comparison.** Replace point-estimate bars with bars that carry the 95% confidence interval — the CI is the information.
# - **The abstract IS the poster's lead paragraph.** Reuse your polished M3 abstract; don't water it down.
# - **Caption every figure.** Axis labels without a takeaway caption force the reader to guess. One sentence per figure is the floor.
# - **Posters are read at a distance** — headings legible from five feet, body text from three.
# - **Filename discipline everywhere** — `NN.pdf` and `NN_final.ipynb` for the project and `NN_kaggle_code.ipynb` for the Kaggle notebook each cost -10 if misnamed, and the Kaggle team must be named `Group NN` (participation hit if wrong).
# - **Don't chase the public Kaggle leaderboard** — trust your cross-validated AUC; the private leaderboard is what grades you.
# - **The final notebook must run clean** — a fresh Runtime → Run All with no errors, including the saved champion artifacts. Have a teammate verify on a fresh runtime before you submit.
# - **Cite any AI tool you used**, per the syllabus AI policy — a short note at the end of each notebook (model + how it was used).
#
# ---

# %% [markdown]
# ## Participation Assignment Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Read the full M4 milestone guidelines** and the **Course Case Competition** instructions posted on Brightspace.
# 2. **Discuss with your group:** who runs the one-shot test-set evaluation, who assembles the poster, who owns the final Kaggle notebook, who verifies the reproducible run? Decide before delivery week — splitting the work badly is the most common reason groups submit late.
# 3. **Save a copy** — `File → Save a copy in Drive`, or download as `.ipynb`.
# 4. **Submit** — upload the `.ipynb` file to the Notebook 20 participation assignment on Brightspace.
#
# ### Before the Course Closes, Check:
#
# - [ ] **M4 poster** `NN.pdf` and final notebook `NN_final.ipynb` submitted — filenames exactly right (no section number; -10 if wrong).
# - [ ] The **one-shot test-set evaluation** is done, with the INSIDE / ABOVE / BELOW verdict on the poster and in the notebook.
# - [ ] `NN_final.ipynb` completes a fresh **Runtime → Run All** with no errors and includes the one-shot test-set evaluation (the INSIDE / ABOVE / BELOW verdict).
# - [ ] **Kaggle** team named `Group NN`, final submission in, and `NN_kaggle_code.ipynb` uploaded on Brightspace — filename exact (-10 if wrong).
# - [ ] **Confidential peer evaluation** submitted (each member individually).
# - [ ] **Course reflection survey** completed (each member individually).
#
# ### Next Step:
#
# - **That's a wrap.** Notebook 20 is the final notebook of QM47400. Submit the deliverables above and the course is complete.
#
# ---

# %% [markdown]
# ## Bibliography
#
# - Provost, F., & Fawcett, T. (2013). *Data Science for Business* — End-to-end predictive modeling workflow and stakeholder communication.
# - James, G., Witten, D., Hastie, T., & Tibshirani, R. (2021). *An Introduction to Statistical Learning with Python* — Cross-validation, model selection, and honest test-set evaluation.
# - scikit-learn User Guide: [Common pitfalls](https://scikit-learn.org/stable/common_pitfalls.html) — Especially leakage and improper evaluation.
#
# ---

# %% [markdown]
# You took one question from a blank notebook to a baseline, to a tuned champion, to a public-facing poster backed by an honest one-shot test — and shipped a Kaggle model alongside it. That is the full arc of an applied predictive-analytics project, and it is genuinely resume-worthy. Keep the discipline that got you here: frame the question, respect the lockbox, trust the confidence interval, and tell the story clearly.
#
# <center>
#
# **Thank you!**
#
# </center>
